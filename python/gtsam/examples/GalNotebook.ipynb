# %%
np.set_printoptions(precision=5, suppress=False, linewidth=400)
from GalPythonRaw import *
# Out:
# ======= Running SingleStepDebug Test =======
# === PYTHON INTEGRATION STEP ===
# Input acc:  -2.5068965533954604 0.8758268073285302 4.864379548870891
# Input gyro: -0.9001066222965415 0.3983943899180935 -0.10436735729977142
# Input dt: 0.01
# Full measurement w: -0.900107 0.398394 -0.104367 -2.506897 0.875827 4.864380 0.000000 0.000000 0.000000 1.000000
# Bias vector (10D): 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
# Unbiased measurement: -0.900107 0.398394 -0.104367 -2.506897 0.875827 4.864380 0.000000 0.000000 0.000000 1.000000
# Tangent coeffs (after reordering): 0.000000 0.000000 0.000000 -2.506897 0.875827 4.864380 -0.900107 0.398394 -0.104367 1.000000
# Tangent coeffs (after dt scaling): 0.000000 0.000000 0.000000 -0.025069 0.008758 0.048644 -0.009001 0.003984 -0.001044 0.010000
# Left Jacobian shape: 10x10
# ...

# %%
plt.imshow(pd.DataFrame(gtsamcpp_jac - actualJxi))

# %%
pd.DataFrame(gtsamcpp_cov - actualCov).abs().max().max()
# Out:
# 4.70233605616277e-14
